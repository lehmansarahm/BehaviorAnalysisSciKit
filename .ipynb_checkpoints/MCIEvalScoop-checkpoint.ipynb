# %%
# %run -i 'load_notebook_finder.py'
sys.meta_path.append(NotebookFinder())
import MCIEval

train_new_data = True
task_name = "scoop"
# Out:
# importing Jupyter notebook from MCIEval.ipynb
# importing Jupyter notebook from MCIBase.ipynb

# %%
if (train_new_data):
    print("# -------------------------------------------------------------------")
    print("    TRAINING CLASSIFIERS WITH YA-SINGLE BREAKFAST, 'SCOOP' TASKS    ")
    print("# -------------------------------------------------------------------")
    print("")

    rf_clf, svm_clf, knn_clf = MCIEval.train_classifiers(filename=MCIEval.MCIBase.MCI_Constants.YA_SINGLE_BREAKFAST_SCOOP)
    
    print("")
    print("# -------------------------------------------------------------------")
    print("    DUMPING TRAINED CLASSIFIER MODELS TO LOCAL FILES    ")
    print("# -------------------------------------------------------------------")

    MCIEval.write_classifiers_to_file(rf_clf, svm_clf, knn_clf, task_name)
# Out:
# # -------------------------------------------------------------------
#     TRAINING CLASSIFIERS WITH YA-SINGLE BREAKFAST, 'SCOOP' TASKS
# # -------------------------------------------------------------------
#
# 364 train + 92 test
# 364 values +  364 labels
# 92 values +  92 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (training results)
# # ---------------------------------------------------
#
# Actual Predictions:
# [[287  15]
#  [ 55   7]]
# Perfect Predictions:
# [[302   0]
#  [  0  62]]
#
# Classifier accuracy: [ 0.75        0.8         0.83333333  0.72222222  0.88888889  0.77777778
#   0.72222222  0.77777778  0.88888889  0.77777778  0.83333333  0.83333333
#   0.88888889  0.72222222  0.83333333  0.77777778  0.83333333  0.83333333
#   0.77777778  0.83333333]
#
# Default Precision: 0.318181818182
# Default Recall: 0.112903225806
# Default F-score: 0.166666666667
#
# Micro Precision: 0.807692307692
# Micro Recall: 0.807692307692
# Micro F-score: 0.807692307692
#
# Macro Precision: 0.578681552366
# Macro Recall: 0.531617175817
# Macro F-score: 0.528985507246
#
# Weighted Precision: 0.750439618861
# Weighted Recall: 0.807692307692
# Weighted F-score: 0.767877050486
#
# # ---------------------------------------------------
#     RANDOM FOREST (testing results)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.902173913043
# Micro Recall: 0.902173913043
# Micro F-score: 0.902173913043
#
# Macro Precision: 0.451086956522
# Macro Recall: 0.5
# Macro F-score: 0.474285714286
#
# Weighted Precision: 0.813917769376
# Weighted Recall: 0.902173913043
# Weighted F-score: 0.855776397516
#
# # ---------------------------------------------------
#     SVM (training results)
# # ---------------------------------------------------
#
# Actual Predictions:
# [[302   0]
#  [ 62   0]]
# Perfect Predictions:
# [[302   0]
#  [  0  62]]
#
# Classifier accuracy: [ 0.8         0.8         0.83333333  0.83333333  0.83333333  0.83333333
#   0.83333333  0.83333333  0.83333333  0.83333333  0.83333333  0.83333333
#   0.83333333  0.83333333  0.83333333  0.83333333  0.83333333  0.83333333
#   0.83333333  0.83333333]
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.82967032967
# Micro Recall: 0.82967032967
# Micro F-score: 0.82967032967
#
# Macro Precision: 0.414835164835
# Macro Recall: 0.5
# Macro F-score: 0.453453453453
#
# Weighted Precision: 0.688352855935
# Weighted Recall: 0.82967032967
# Weighted F-score: 0.752433752434
#
# # ---------------------------------------------------
#     SVM (testing results)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.902173913043
# Micro Recall: 0.902173913043
# Micro F-score: 0.902173913043
#
# Macro Precision: 0.451086956522
# Macro Recall: 0.5
# Macro F-score: 0.474285714286
#
# Weighted Precision: 0.813917769376
# Weighted Recall: 0.902173913043
# Weighted F-score: 0.855776397516
#
# # ---------------------------------------------------
#     K-NEAREST NEIGHBORS (training results)
# # ---------------------------------------------------
#
# Actual Predictions:
# [[283  19]
#  [ 50  12]]
# Perfect Predictions:
# [[302   0]
#  [  0  62]]
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Classifier accuracy: [ 0.6         0.85        0.83333333  0.77777778  0.94444444  0.83333333
#   0.77777778  0.83333333  0.77777778  0.83333333  0.61111111  0.77777778
#   0.88888889  0.77777778  0.94444444  0.77777778  0.88888889  0.83333333
#   0.88888889  0.77777778]
#
# Default Precision: 0.387096774194
# Default Recall: 0.193548387097
# Default F-score: 0.258064516129
#
# Micro Precision: 0.81043956044
# Micro Recall: 0.81043956044
# Micro F-score: 0.81043956044
#
# Macro Precision: 0.618473312022
# Macro Recall: 0.565317239906
# Macro F-score: 0.574701549403
#
# Weighted Precision: 0.771029271029
# Weighted Recall: 0.81043956044
# Weighted F-score: 0.783473219694
#
# # ---------------------------------------------------
#     K-NEAREST NEIGHBORS (testing results)
# # ---------------------------------------------------
#
# Default Precision: 0.285714285714
# Default Recall: 0.222222222222
# Default F-score: 0.25
#
# Micro Precision: 0.869565217391
# Micro Recall: 0.869565217391
# Micro F-score: 0.869565217391
#
# Macro Precision: 0.601680672269
# Macro Recall: 0.580990629183
# Macro F-score: 0.589285714286
#
# Weighted Precision: 0.855827548411
# Weighted Recall: 0.869565217391
# Weighted F-score: 0.862189440994
#
# # -------------------------------------------------------------------
#     DUMPING TRAINED CLASSIFIER MODELS TO LOCAL FILES
# # -------------------------------------------------------------------

# %%
print("# -------------------------------------------------------------------")
print("    RETRIEVING TRAINED CLASSIFIER MODELS FROM LOCAL FILES    ")
print("# -------------------------------------------------------------------")

rfCLF, svmCLF, knnCLF = MCIEval.load_classifiers_from_file(task_name)
# Out:
# # -------------------------------------------------------------------
#     RETRIEVING TRAINED CLASSIFIER MODELS FROM LOCAL FILES
# # -------------------------------------------------------------------

# %%
print("# -------------------------------------------------------------------")
print("    TESTING CLASSIFIERS AGAINST YA-SINGLE LUNCH, 'SCOOP' TASKS    ")
print("# -------------------------------------------------------------------")
print("")

MCIEval.validate_classifier_predictions(rfCLF, svmCLF, knnCLF, MCIEval.MCIBase.MCI_Constants.YA_SINGLE_LUNCH_SCOOP)
# Out:
# # -------------------------------------------------------------------
#     TESTING CLASSIFIERS AGAINST YA-SINGLE LUNCH, 'SCOOP' TASKS
# # -------------------------------------------------------------------
#
# 547 values +  547 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.930530164534
# Micro Recall: 0.930530164534
# Micro F-score: 0.930530164534
#
# Macro Precision: 0.465265082267
# Macro Recall: 0.5
# Macro F-score: 0.482007575758
#
# Weighted Precision: 0.865886387107
# Weighted Recall: 0.930530164534
# Weighted F-score: 0.897045177552
#
# # ---------------------------------------------------
#     SVM (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.930530164534
# Micro Recall: 0.930530164534
# Micro F-score: 0.930530164534
#
# Macro Precision: 0.465265082267
# Macro Recall: 0.5
# Macro F-score: 0.482007575758
#
# Weighted Precision: 0.865886387107
# Weighted Recall: 0.930530164534
# Weighted F-score: 0.897045177552
#
# # ---------------------------------------------------
#     K-NEAREST NEIGHBORS (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0625
# Default Recall: 0.0789473684211
# Default F-score: 0.0697674418605
#
# Micro Precision: 0.853747714808
# Micro Recall: 0.853747714808
# Micro F-score: 0.853747714808
#
# Macro Precision: 0.496179859719
# Macro Recall: 0.49526936201
# Macro F-score: 0.495201181248
#
# Weighted Precision: 0.869604382439
# Weighted Recall: 0.853747714808
# Weighted F-score: 0.861525296881
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print("# -------------------------------------------------------------------")
print("    TESTING CLASSIFIERS AGAINST OA BREAKFAST, 'SCOOP' TASKS    ")
print("# -------------------------------------------------------------------")
print("")

MCIEval.validate_classifier_predictions(rfCLF, svmCLF, knnCLF, 
                                        MCIEval.MCIBase.MCI_Constants.OA_BREAKFAST_SCOOP)
# Out:
# # -------------------------------------------------------------------
#     TESTING CLASSIFIERS AGAINST OA BREAKFAST, 'SCOOP' TASKS
# # -------------------------------------------------------------------
#
# 312 values +  312 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.852564102564
# Micro Recall: 0.852564102564
# Micro F-score: 0.852564102564
#
# Macro Precision: 0.426282051282
# Macro Recall: 0.5
# Macro F-score: 0.460207612457
#
# Weighted Precision: 0.726865548981
# Weighted Recall: 0.852564102564
# Weighted F-score: 0.784712980215
#
# # ---------------------------------------------------
#     SVM (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.852564102564
# Micro Recall: 0.852564102564
# Micro F-score: 0.852564102564
#
# Macro Precision: 0.426282051282
# Macro Recall: 0.5
# Macro F-score: 0.460207612457
#
# Weighted Precision: 0.726865548981
# Weighted Recall: 0.852564102564
# Weighted F-score: 0.784712980215
#
# # ---------------------------------------------------
#     K-NEAREST NEIGHBORS (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0869565217391
# Default Recall: 0.0434782608696
# Default F-score: 0.0579710144928
#
# Micro Precision: 0.791666666667
# Micro Recall: 0.791666666667
# Micro F-score: 0.791666666667
#
# Macro Precision: 0.467353693396
# Macro Recall: 0.482265446224
# Macro F-score: 0.470426948688
#
# Weighted Precision: 0.735582468281
# Weighted Recall: 0.791666666667
# Weighted F-score: 0.761261261261
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print("# -------------------------------------------------------------------")
print("    EXPLICIT PREDICTIONS FOR OA BREAKFAST, NO TASK LABELS    ")
print("# -------------------------------------------------------------------")

predictions = MCIEval.get_classifier_predictions(rfCLF, svmCLF, knnCLF)
MCIEval.MCIBase.write_output_file("MCIEvalScoop.csv", predictions)
# print(predictions)
# Out:
# # -------------------------------------------------------------------
#     EXPLICIT PREDICTIONS FOR OA BREAKFAST, NO TASK LABELS
# # -------------------------------------------------------------------
#
# # ---------------------------------------------------
#     RANDOM FOREST (predictions)
# # ---------------------------------------------------
# 1648 values +  1648 labels
#
# # ---------------------------------------------------
#     SVM (predictions)
# # ---------------------------------------------------
# 1648 values +  1648 labels
#
# # ---------------------------------------------------
#     K-NEAREST NEIGHBORS (predictions)
# # ---------------------------------------------------
# 1648 values +  1648 labels
