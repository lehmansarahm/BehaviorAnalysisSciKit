# %%
# %run -i 'load_notebook_finder.py'
sys.meta_path.append(NotebookFinder())
import MCIEval

train_new_data = False
task_name = "stir"
# Out:
# importing Jupyter notebook from MCIEval.ipynb
# importing Jupyter notebook from MCIBase.ipynb

# %%
if (train_new_data):
    print("# -------------------------------------------------------------------")
    print("    TRAINING CLASSIFIERS WITH YA-SINGLE BREAKFAST, 'STIR' TASKS    ")
    print("# -------------------------------------------------------------------")
    print("")

    rf_clf, svm_clf, knn_clf = MCIEval.train_classifiers(filename=MCIEval.MCIBase.MCI_Constants.YA_SINGLE_BREAKFAST_STIR)
    
    print("")
    print("# -------------------------------------------------------------------")
    print("    DUMPING TRAINED CLASSIFIER MODELS TO LOCAL FILES    ")
    print("# -------------------------------------------------------------------")

    MCIEval.write_classifiers_to_file(rf_clf, svm_clf, knn_clf, task_name)
# Out:
# # -------------------------------------------------------------------
#     TRAINING CLASSIFIERS WITH YA-SINGLE BREAKFAST, 'STIR' TASKS
# # -------------------------------------------------------------------
#
# 364 train + 92 test
# 364 values +  364 labels
# 92 values +  92 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (training results)
# # ---------------------------------------------------
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/model_selection/_split.py:581: Warning: The least populated class in y has only 19 members, which is too few. The minimum number of groups for any class cannot be less than n_splits=20.
#   % (min_groups, self.n_splits)), Warning)
# Actual Predictions:
# [[342   3]
#  [ 19   0]]
# Perfect Predictions:
# [[345   0]
#  [  0  19]]
# ...

# %%
print("# -------------------------------------------------------------------")
print("    RETRIEVING TRAINED CLASSIFIER MODELS FROM LOCAL FILES    ")
print("# -------------------------------------------------------------------")

rfCLF, svmCLF, knnCLF = MCIEval.load_classifiers_from_file(task_name)
# Out:
# # -------------------------------------------------------------------
#     RETRIEVING TRAINED CLASSIFIER MODELS FROM LOCAL FILES
# # -------------------------------------------------------------------

# %%
print("# -------------------------------------------------------------------")
print("    TESTING CLASSIFIERS AGAINST YA-SINGLE LUNCH, 'STIR' TASKS    ")
print("# -------------------------------------------------------------------")
print("")

MCIEval.validate_classifier_predictions(rfCLF, svmCLF, knnCLF, MCIEval.MCIBase.MCI_Constants.YA_SINGLE_LUNCH_STIR)
# Out:
# # -------------------------------------------------------------------
#     TESTING CLASSIFIERS AGAINST YA-SINGLE LUNCH, 'STIR' TASKS
# # -------------------------------------------------------------------
#
# 547 values +  547 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 1.0
# Micro Recall: 1.0
# Micro F-score: 1.0
#
# Macro Precision: 1.0
# Macro Recall: 1.0
# Macro F-score: 1.0
#
# Weighted Precision: 1.0
# Weighted Recall: 1.0
# Weighted F-score: 1.0
#
# # ---------------------------------------------------
#     SVM (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 1.0
# Micro Recall: 1.0
# Micro F-score: 1.0
#
# Macro Precision: 1.0
# Macro Recall: 1.0
# ...

# %%
print("# -------------------------------------------------------------------")
print("    TESTING CLASSIFIERS AGAINST OA BREAKFAST, 'STIR' TASKS    ")
print("# -------------------------------------------------------------------")
print("")

MCIEval.validate_classifier_predictions(rfCLF, svmCLF, knnCLF, 
                                        MCIEval.MCIBase.MCI_Constants.OA_BREAKFAST_STIR)
# Out:
# # -------------------------------------------------------------------
#     TESTING CLASSIFIERS AGAINST OA BREAKFAST, 'STIR' TASKS
# # -------------------------------------------------------------------
#
# 312 values +  312 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.942307692308
# Micro Recall: 0.942307692308
# Micro F-score: 0.942307692308
#
# Macro Precision: 0.471153846154
# Macro Recall: 0.5
# Macro F-score: 0.485148514851
#
# Weighted Precision: 0.887943786982
# Weighted Recall: 0.942307692308
# Weighted F-score: 0.914318354912
#
# # ---------------------------------------------------
#     SVM (predictions)
# # ---------------------------------------------------
#
# Default Precision: 0.0
# Default Recall: 0.0
# Default F-score: 0.0
#
# Micro Precision: 0.942307692308
# ...

# %%
print("# -------------------------------------------------------------------")
print("    EXPLICIT PREDICTIONS FOR OA BREAKFAST, NO TASK LABELS    ")
print("# -------------------------------------------------------------------")

MCIEval.get_classifier_predictions(rfCLF, svmCLF, knnCLF)
# Out:
# # -------------------------------------------------------------------
#     EXPLICIT PREDICTIONS FOR OA BREAKFAST, NO TASK LABELS
# # -------------------------------------------------------------------
#
# # ---------------------------------------------------
#     RANDOM FOREST (predictions)
# # ---------------------------------------------------
# 464 values +  464 labels
# Source: oa_OA10_06-03-2016_14_37_18_292 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_382 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_472 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_562 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_652 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_742 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_832 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_922 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_1012 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_1102 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_1192 Prediction: 0
# ...
