# %%
train_data_set = MCIBase.load_mci_file(filename=MCIBase.MCI_Constants.YA_SINGLE_BREAKFAST_SELECT)
train_values, train_labels, test_values, test_labels = MCIBase.split_train_test_matrices(train_data_set)

print("")
print("# ---------------------------------------------------")
print("    RANDOM FOREST (training results)    ")
print("# ---------------------------------------------------")
rfCLF = MCIBase.train_rf_classifier(train_values, train_labels)

print("")
print("# ---------------------------------------------------")
print("    SVM (training results)    ")
print("# ---------------------------------------------------")
svmCLF = MCIBase.train_svm_classifier(train_values, train_labels)

print("")
print("# ---------------------------------------------------")
print("    K-NEAREST NEIGHBORS (training results)    ")
print("# ---------------------------------------------------")
knnCLF = MCIBase.train_knn_classifier(train_values, train_labels)
# Out:
# 364 train + 92 test
# 364 values +  364 labels
# 92 values +  92 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (training results)
# # ---------------------------------------------------
#
# Actual Predictions:
# [[180  51]
#  [ 85  48]]
# Perfect Predictions:
# [[231   0]
#  [  0 133]]
#
# Classifier accuracy: [ 0.73684211  0.57894737  0.42105263  0.57894737  0.68421053  0.52631579
#   0.47368421  0.89473684  0.63157895  0.68421053  0.47368421  0.55555556
#   0.66666667  0.70588235  0.76470588  0.64705882  0.58823529  0.76470588
#   0.58823529  0.52941176]
#
# Default Precision: 0.484848484848
# Default Recall: 0.360902255639
# Default F-score: 0.413793103448
#
# Micro Precision: 0.626373626374
# Micro Recall: 0.626373626374
# Micro F-score: 0.626373626374
#
# Macro Precision: 0.582046883934
# Macro Recall: 0.57006151743
# Macro F-score: 0.569799777531
#
# Weighted Precision: 0.608215683687
# Weighted Recall: 0.626373626374
# ...

# %%
ya_lunch = MCIBase.load_mci_file(filename=MCIBase.MCI_Constants.YA_SINGLE_LUNCH_SELECT)
ya_lunch_values, ya_lunch_labels = MCIBase.get_value_label_matrices(ya_lunch)

print("")
print("# ---------------------------------------------------")
print("    RANDOM FOREST (YA lunch 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.validate_classifier_predictions(rfCLF, ya_lunch_values, ya_lunch_labels)

print("")
print("# ---------------------------------------------------")
print("    SVM (YA lunch 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.validate_classifier_predictions(svmCLF, ya_lunch_values, ya_lunch_labels)

print("")
print("# ---------------------------------------------------")
print("    K-NEAREST NEIGHBORS (YA lunch 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.validate_classifier_predictions(knnCLF, ya_lunch_values, ya_lunch_labels)
# Out:
# 547 values +  547 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (YA lunch 'select' predictions)
# # ---------------------------------------------------
#
# Actual Predictions:
# [[341  57]
#  [108  41]]
# Perfect Predictions:
# [[398   0]
#  [  0 149]]
#
# Classifier accuracy: [ 0.71428571  0.75        0.71428571  0.60714286  0.78571429  0.75        0.75
#   0.64285714  0.60714286  0.66666667  0.7037037   0.22222222  0.7037037
#   0.74074074  0.7037037   0.7037037   0.74074074  0.7037037   0.73076923
#   0.69230769]
#
# Default Precision: 0.418367346939
# Default Recall: 0.275167785235
# Default F-score: 0.331983805668
#
# Micro Precision: 0.698354661792
# Micro Recall: 0.698354661792
# Micro F-score: 0.698354661792
#
# Macro Precision: 0.58891641289
# Macro Recall: 0.565975852416
# Macro F-score: 0.568589305431
#
# Weighted Precision: 0.666552093735
# Weighted Recall: 0.698354661792
# Weighted F-score: 0.67629455121
#
# ...

# %%
oa_breakfast = MCIBase.load_mci_file(filename=MCIBase.MCI_Constants.OA_BREAKFAST_SELECT)
oa_breakfast_values, oa_breakfast_labels = MCIBase.get_value_label_matrices(oa_breakfast)

print("")
print("# ---------------------------------------------------")
print("    RANDOM FOREST (OA breakfast 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.validate_classifier_predictions(rfCLF, oa_breakfast_values, oa_breakfast_labels)

print("")
print("# ---------------------------------------------------")
print("    SVM (OA breakfast 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.validate_classifier_predictions(svmCLF, oa_breakfast_values, oa_breakfast_labels)

print("")
print("# ---------------------------------------------------")
print("    K-NEAREST NEIGHBORS (OA breakfast 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.validate_classifier_predictions(knnCLF, oa_breakfast_values, oa_breakfast_labels)
# Out:
# 312 values +  312 labels
#
# # ---------------------------------------------------
#     RANDOM FOREST (OA breakfast 'select' predictions)
# # ---------------------------------------------------
#
# Actual Predictions:
# [[154  48]
#  [ 77  33]]
# Perfect Predictions:
# [[202   0]
#  [  0 110]]
#
# Classifier accuracy: [ 0.58823529  0.58823529  0.5625      0.625       0.5         0.5         0.5
#   0.6875      0.6875      0.75        0.66666667  0.6         0.73333333
#   0.6         0.46666667  0.6         0.4         0.66666667  0.6
#   0.73333333]
#
# Default Precision: 0.407407407407
# Default Recall: 0.3
# Default F-score: 0.34554973822
#
# Micro Precision: 0.599358974359
# Micro Recall: 0.599358974359
# Micro F-score: 0.599358974359
#
# Macro Precision: 0.537037037037
# Macro Recall: 0.531188118812
# Macro F-score: 0.528433067724
#
# Weighted Precision: 0.575261158594
# Weighted Recall: 0.599358974359
# Weighted F-score: 0.582360203347
#
# ...

# %%
oa_breakfast = MCIBase.load_mci_file(filename=MCIBase.MCI_Constants.OA_BREAKFAST)

print("")
print("# ---------------------------------------------------")
print("    RANDOM FOREST (OA breakfast 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.get_trained_classifier_predictions(oa_breakfast, rfCLF)

print("")
print("# ---------------------------------------------------")
print("    SVM (OA breakfast 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.get_trained_classifier_predictions(oa_breakfast, svmCLF)

print("")
print("# ---------------------------------------------------")
print("    K-NEAREST NEIGHBORS (OA breakfast 'select' predictions)    ")
print("# ---------------------------------------------------")
MCIBase.get_trained_classifier_predictions(oa_breakfast, knnCLF)
# Out:
# # ---------------------------------------------------
#     RANDOM FOREST (OA breakfast 'select' predictions)
# # ---------------------------------------------------
# 464 values +  464 labels
# Source: oa_OA10_06-03-2016_14_37_18_292 Prediction: 1
# Source: oa_OA10_06-03-2016_14_37_18_382 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_472 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_562 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_652 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_742 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_832 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_922 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_1012 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_1102 Prediction: 1
# Source: oa_OA10_06-03-2016_14_37_18_1192 Prediction: 1
# Source: oa_OA10_06-03-2016_14_37_18_1372 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_1462 Prediction: 0
# Source: oa_OA10_06-03-2016_14_37_18_1552 Prediction: 0
# ...
